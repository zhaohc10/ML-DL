# %% [markdown]
# # Run logistic regression model
#
# ## load dataset

# %%
# %matplotlib inline 
#%matplotlib qt
import pandas as pd

path=r'noExpired.xlsx'
all=pd.read_excel(path)

# %% [markdown]
# ## Manipulate Numeric Feature

# %%
from sklearn.preprocessing import MinMaxScaler
from __future__ import division

scaler = MinMaxScaler()

numeric_cols = ['time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses']
all[ numeric_cols ] = all[ numeric_cols ].astype(float)
all[ numeric_cols ]=all[ numeric_cols ].apply(lambda x: MinMaxScaler().fit_transform(x))
all.head(10)
# Out:
#                race  gender      age admission_type_id  \
# 0         Caucasian  Female  [50-60)          Elective
# 1         Caucasian  Female  [20-30)            Urgent
# 2         Caucasian    Male  [80-90)     Not Available
# 3   AfricanAmerican  Female  [50-60)         Emergency
# 4   AfricanAmerican  Female  [50-60)         Emergency
# 5         Caucasian    Male  [70-80)          Elective
# 7         Caucasian  Female  [50-60)         Emergency
# 8         Caucasian    Male  [50-60)               NaN
# 9         Caucasian    Male  [60-70)          Elective
# 10        Caucasian    Male  [70-80)            Urgent
#
#                              discharge_disposition_id  \
# 0                                  Discharged to home
# 1                                  Discharged to home
# 2   Discharged/transferred to home with home healt...
# 3                                  Discharged to home
# 4                                  Discharged to home
# 5                                  Discharged to home
# 7                                  Discharged to home
# 8                                  Discharged to home
# 9                                  Discharged to home
# 10  Discharged/transferred to a long term care hos...
#
#                            admission_source_id  time_in_hospital  \
# 0                           Physician Referral          0.000000
# 1                           Physician Referral          0.076923
# 2                                          NaN          0.461538
# 3   Transfer from another health care facility          0.230769
# 4                               Emergency Room          0.307692
# 5                           Physician Referral          0.230769
# 7                               Emergency Room          0.076923
# 8                                          NaN          0.153846
# 9                           Physician Referral          0.307692
# 10                          Physician Referral          1.000000
#
#                   medical_specialty  num_lab_procedures  num_procedures  \
# 0                     Surgery-Neuro            0.285714        0.666667
# 1                                 ?            0.058824        0.833333
# 2            Family/GeneralPractice            0.092437        0.000000
# 3                                 ?            0.268908        0.166667
# 4                        Psychiatry            0.252101        0.000000
# 5                        Cardiology            0.235294        0.000000
# 7                                 ?            0.403361        0.166667
# 8            Family/GeneralPractice            0.445378        0.000000
# 9   Surgery-Cardiovascular/Thoracic            0.386555        0.333333
# 10  Surgery-Cardiovascular/Thoracic            0.369748        0.333333
#
#                           ...                          glipizide.metformin  \
# 0                         ...                                           No
# 1                         ...                                           No
# 2                         ...                                           No
# 3                         ...                                           No
# 4                         ...                                           No
# 5                         ...                                           No
# 7                         ...                                           No
# 8                         ...                                           No
# 9                         ...                                           No
# 10                        ...                                           No
#
#     glimepiride.pioglitazone  metformin.rosiglitazone  metformin.pioglitazone  \
# 0                         No                       No                      No
# 1                         No                       No                      No
# 2                         No                       No                      No
# 3                         No                       No                      No
# 4                         No                       No                      No
# 5                         No                       No                      No
# 7                         No                       No                      No
# 8                         No                       No                      No
# 9                         No                       No                      No
# 10                        No                       No                      No
#
#    change diabetesMed readmitted  \
# 0      No          No          0
# 1      No          No          0
# 2      No         Yes          1
# 3      No         Yes          0
# 4      Ch         Yes          0
# 5      No         Yes          0
# 7      No         Yes          0
# 8      No          No          0
# 9      No         Yes          1
# 10     Ch         Yes          0
#
#                                           diag_1_desc  \
# 0                  Spinal stenosis in cervical region
# 1   First-degree perineal laceration, unspecified ...
# 2   Pneumococcal pneumonia [Streptococcus pneumoni...
# 3                      Cellulitis and abscess of face
# 4   Bipolar I disorder, single manic episode, unsp...
# 5               Congestive heart failure, unspecified
# 7   Other and unspecified noninfectious gastroente...
# 8               Congestive heart failure, unspecified
# 9                            Atherosclerosis of aorta
# 10           Nervous system complication, unspecified
#
#                                           diag_2_desc  \
# 0                  Spinal stenosis in cervical region
# 1   Diabetes mellitus of mother, complicating preg...
# 2               Congestive heart failure, unspecified
# 3   Streptococcus infection in conditions classifi...
# 4   Diabetes mellitus without mention of complicat...
# 5             Paroxysmal supraventricular tachycardia
# 7   Diverticulosis of small intestine (without men...
# 8                             Endomyocardial fibrosis
# 9                    Postoperative shock, unspecified
# 10              Congestive heart failure, unspecified
#
#                                           diag_3_desc
# 0                 Effusion of joint, site unspecified
# 1                                Sideroblastic anemia
# 2                Hyperosmolality and/or hypernatremia
# 3   Diabetes mellitus without mention of complicat...
# 4                           Depressive type psychosis
# 5   Coronary atherosclerosis of unspecified type o...
# 7   Internal hemorrhoids without mention of compli...
# 8                 Viral hepatitis A with hepatic coma
# 9                    Postoperative shock, unspecified
# 10  Pleurisy without mention of effusion or curren...
#
# [10 rows x 49 columns]

# %% [markdown]
# ## Manipulate Categorical Feature

# %%
x_num_all = all[ numeric_cols ].as_matrix()
# categorical

collect_cat=['gender','age','admission_type_id','admission_source_id','medical_specialty']
cat_all = all[ collect_cat ]


fac_x_cat_all = pd.DataFrame()
cat_cols = list(cat_all.columns.values)
for col in cat_cols:
    all_cur, _ = pd.factorize(cat_all[col])
    fac_x_cat_all[col] = all_cur

fac_x_cat_all = fac_x_cat_all.as_matrix()

import numpy as np
x_all = np.hstack(( x_num_all, fac_x_cat_all ))

# %%
from sklearn.preprocessing import label_binarize
# y
y_all = all.readmitted

# %% [markdown]
# ## Split dataset to Train and Test

# %%
from sklearn.cross_validation import train_test_split
#train-test split
x_train, x_test, y_train, y_test = train_test_split(x_all, y_all, test_size=.25,random_state=24)

# %% [markdown]
# ## Train LR model when parameter is default

# %%
from sklearn import linear_model
logReg=linear_model.LogisticRegression()

# %%
# Recursive Feature Elimination
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load the iris datasets
dataset = datasets.load_iris()
# create a base classifier used to evaluate a subset of attributes
model = LogisticRegression()
# create the RFE model and select 3 attributes
rfe = RFE(model, 3)
rfe = rfe.fit(x_train, y_train)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)

# %%
import time
#training
st = time.time()
print "training started"
logReg.fit( x_train, y_train )
print "training ended"
et = time.time()
tt = et - st
print "Training Time = " + str(tt) + "\n"
# Out:
# training started
# training ended
# Training Time = 0.0450000762939

# %% [markdown]
# ### Weight, bias and number of zerosof LR trained model

# %%
w = logReg.coef_ 
b = logReg.intercept_[0] 
ze=0.00000000e+00
numZeros=sum(1 for i in w.flat if i==ze)
print "Number of zeros: %d" %numZeros
w,b
# Out:
# Number of zeros: 0
# (array([[-0.08426114,  0.72609321, -0.20079932,  0.1136782 ,  1.79902396,
#           1.63984871,  4.35506032,  1.05331031, -0.04532974, -0.0201815 ,
#          -0.05711488, -0.02946242, -0.01493235]]), -1.2846473483890275)

# %% [markdown]
# ### Score of trained LR model

# %%
print 'Score of trained LR model %.3f' %logReg.score(x_train,y_train)
# Out:
# Score of trained LR model 0.636

# %% [markdown]
# ### ROC and AUC of trained LR model

# %%
from sklearn.metrics import precision_recall_curve, roc_curve,auc
#predictions
pred = logReg.predict( x_test )

fpr, tpr, thresholds =roc_curve(y_test, pred)
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc) 
plt.plot([0, 1], [0, 1], 'k--') 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.legend(bbox_to_anchor=(0.9, 0.2), 
    bbox_transform=plt.gcf().transFigure) 
plt.show()
# Out:
# Area under the ROC curve : 0.581555

# %% [markdown]
# ## Find best LR Model using conventional GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import StratifiedKFold
from sklearn.grid_search import GridSearchCV

param_grid = {'penalty':['l1','l2'],'C': [0.001, 0.01, 0.1, 1,10,100,1000,1e4,1e5,1e6] }
lr=LogisticRegression()
clf = GridSearchCV(lr, 
                   param_grid,
                   scoring="accuracy",
                   cv=StratifiedKFold(y_all, n_folds=10),
                   verbose=1)

# %time clf.fit(x_all, y_all)
# Out:
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  50 jobs       | elapsed:    1.6s
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# Wall time: 12.6 s
# [Parallel(n_jobs=1)]: Done 200 jobs       | elapsed:   12.4s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:   12.4s finished
# GridSearchCV(cv=sklearn.cross_validation.StratifiedKFold(labels=[0 0 ..., 0 0], n_folds=10, shuffle=False, random_state=None),
#        error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0),
#        fit_params={}, iid=True, loss_func=None, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000.0, 100000.0, 1000000.0]},
#        pre_dispatch='2*n_jobs', refit=True, score_func=None,
#        scoring='accuracy', verbose=1)

# %% [markdown]
# ### The best score and corresponding parameters after using GridSearchCV

# %%
clf.best_score_, clf.best_params_
# Out:
# (0.63946965833758285, {'C': 10, 'penalty': 'l1'})

# %% [markdown]
# ### The weight, bias and number of zeros of best LR moedel after using GridSearchCV

# %%
w_best=clf.best_estimator_.coef_ 
b_best=clf.best_estimator_.intercept_[0] 
ze=0.00000000e+00
numZeros=sum(1 for i in clf.best_estimator_.coef_.flat if i==ze)
print "Number of zeros: %d" %numZeros
w_best,b_best
# Out:
# Number of zeros: 0
# (array([[-0.00987435,  0.84234513, -0.26828671,  0.05061488,  3.14004529,
#           8.74066951,  4.44303744,  1.11274159, -0.05512756, -0.01971071,
#          -0.07039101, -0.03039749, -0.01429826]]), -1.3735248360878798)

# %% [markdown]
# ### ROC using suitable LR model after using GridSearchCV

# %%
pred_opt = clf.predict( x_test )
fpr, tpr, thresholds =roc_curve(y_test, pred_opt)

roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)

plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc) 
plt.plot([0, 1], [0, 1], 'k--') 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.legend(bbox_to_anchor=(0.9, 0.2), 
    bbox_transform=plt.gcf().transFigure) 
plt.show()
# Out:
# Area under the ROC curve : 0.587565
