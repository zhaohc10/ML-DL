# %% [markdown]
# # 01 Data Processing
#
# ## Load original file and display first 3 records

# %%
import pandas as pd
# read excel file and return first 2 rows
path=r'Test.xlsx'
df=pd.read_excel(path)
df.head(3)
# Out:
#         race  gender      age admission_type_id  \
# 0  Caucasian  Female  [50-60)          Elective
# 1  Caucasian  Female  [20-30)            Urgent
# 2  Caucasian    Male  [80-90)     Not Available
#
#                             discharge_disposition_id admission_source_id  \
# 0                                 Discharged to home  Physician Referral
# 1                                 Discharged to home  Physician Referral
# 2  Discharged/transferred to home with home healt...                 NaN
#
#    time_in_hospital       medical_specialty  num_lab_procedures  \
# 0                 1           Surgery-Neuro                  35
# 1                 2                       ?                   8
# 2                 7  Family/GeneralPractice                  12
#
#    num_procedures                  ...                   glipizide.metformin  \
# 0               4                  ...                                    No
# 1               5                  ...                                    No
# 2               0                  ...                                    No
#
#    glimepiride.pioglitazone  metformin.rosiglitazone  metformin.pioglitazone  \
# 0                        No                       No                      No
# 1                        No                       No                      No
# 2                        No                       No                      No
#
#   change diabetesMed readmitted  \
# 0     No          No      False
# 1     No          No      False
# 2     No         Yes       True
#
#                                          diag_1_desc  \
# 0                 Spinal stenosis in cervical region
# 1  First-degree perineal laceration, unspecified ...
# 2  Pneumococcal pneumonia [Streptococcus pneumoni...
#
#                                          diag_2_desc  \
# 0                 Spinal stenosis in cervical region
# 1  Diabetes mellitus of mother, complicating preg...
# 2              Congestive heart failure, unspecified
#
#                             diag_3_desc
# 0   Effusion of joint, site unspecified
# 1                  Sideroblastic anemia
# 2  Hyperosmolality and/or hypernatremia
#
# [3 rows x 49 columns]

# %% [markdown]
# ## Save file without expired record

# %%
# filter the records
df1=df[df['discharge_disposition_id']!="Expired"]
# save the preProcess to the new file
writer_noExpired=pd.ExcelWriter('noExpired.xlsx',engine='xlsxwriter')
df1.to_excel(writer_noExpired,index=True,sheet_name='noExpired_diabetes.csv')
writer_noExpired.save()
# return the number of new file
num_rows=len(df1)
print "Number of no expired records is %d" %num_rows
# Out:
# Number of no expired records is 9805
